# %%
import physplot as phys
import numpy as np
from __future__ import division

array1 = np.array([-.176,-.364,-.577,-.839,-1.19,.176,.364,.577,.839,1.19])
array2 = np.array([-4.58,-10.49,-16.3,-25.8,-35.2,4.08,10.34,16.01,24.2,35.7])
errarray2 = np.array([.2,.2,.2,.2,.2,.2,.2,.2,.2,.2])

#plotfit takes in parameters in this order
#phys.plotfit(x,y,dy,title,'xlabel(units)','ylabel(units)','slope units')  Slope units will not render in LaTeX

phys.plotfit(array1,array2,errarray2,'100 turns','tan theta(m)','current (A)','A/m')
# Out:
# Slope =  29.442909056719433   A/m
# Error in slope =  0.08743012548752668   A/m
# Goodness of fit =  117.7256298719206

# %%
import physplot as phys
import numpy as np
from __future__ import division

array1 = np.array([-.176,-.364,-.577,-.839,-1.19,.176,.364,.577,.839,1.19])
array2 = np.array([-2.39,-5.2,-8.09,-13.11,-17.52,1.98,5.22,9.09,12.28,17.83])
errarray2 = np.array([.2,.2,.2,.2,.2,.2,.2,.2,.2,.2])

#plotfit takes in parameters in this order
#phys.plotfit(x,y,dy,title,'xlabel(units)','ylabel(units)','slope units')  Slope units will not render in LaTeX

phys.plotfit(array1,array2,errarray2,'200 turns','tan theta(m)','current (A)','A/m')
# Out:
# Slope =  14.87595846541574   A/m
# Error in slope =  0.08743012548752668   A/m
# Goodness of fit =  38.20939700791768
